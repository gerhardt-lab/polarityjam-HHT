# %%
import pandas as pd

# %%
cond_to_file = {"siCTRL_static": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siCTRL/static/KLF4_siCTRL_static_merged_file.csv",
                "siCTRL_4h": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siCTRL/4h/KLF4_siCTRL_4h_merged_file.csv",
                "siCTRL_16h": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siCTRL/16h/KLF4_siCTRL_16h_merged_file.csv",
                "siSMAD4_static": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siSMAD4/static/KLF4_siSMAD4_static_merged_file.csv",
                "siSMAD4_4h": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siSMAD4/4h/KLF4_siSMAD4_4h_merged_file.csv",
                "siSMAD4_16h": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siSMAD4/16h/KLF4_siSMAD4_16h_merged_file.csv",
                "siAlk1_static": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siAlk1/static/KLF4_siAlk1_static_merged_file.csv",
                "siAlk1_4h": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siAlk1/4h/KLF4_siAlk1_4h_merged_file.csv",
                "siAlk1_16h": "T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siAlk1/16h/KLF4_siAlk1_16h_merged_file.csv",
            #    "siCTRL_static_BSA": "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/4h/static/BSA_statistics_file.csv",
            #    "siCTRL_6dyn_4h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/4h/6dyn/BSA_statistics_file.csv",
            #    "siCTRL_6dyn_16h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/16h/6dyn/BSA_statistics_file.csv",
            #    "siCTRL_18dyn_4h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/4h/18dyn/BSA_statistics_file.csv",
            #    "siCTRL_18dyn_16h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/16h/18dyn/BSA_statistics_file.csv",
            #    "siCTRL_static_BSA_BMP10": "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/4h/static/BMP10_statistics_file.csv",
            #    "siCTRL_6dyn_4h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/4h/6dyn/BMP10_statistics_file.csv",
            #    "siCTRL_6dyn_16h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/16h/6dyn/BMP10_statistics_file.csv",
            #    "siCTRL_18dyn_4h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/4h/18dyn/BMP10_statistics_file.csv",
            #    "siCTRL_18dyn_16h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siCTRL/16h/18dyn/BMP10_statistics_file.csv",
    
                
               # "siSMAD4_static_BSA": "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/4h/static/BSA_statistics_file.csv",
               # "siSMAD4_6dyn_4h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/4h/6dyn/BSA_statistics_file.csv",
               # "siSMAD4_6dyn_16h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/16h/6dyn/BSA_statistics_file.csv",
               # "siSMAD4_18dyn_4h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/4h/18dyn/BSA_statistics_file.csv",
               # "siSMAD4_18dyn_16h_BSA" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/16h/18dyn/BSA_statistics_file.csv",
               # "siSMAD4_static_BSA_BMP10": "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/4h/static/BMP10_statistics_file.csv",
               # "siSMAD4_6dyn_4h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/4h/6dyn/BMP10_statistics_file.csv",
               # "siSMAD4_6dyn_16h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/16h/6dyn/BMP10_statistics_file.csv",
               # "siSMAD4_18dyn_4h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/4h/18dyn/BMP10_statistics_file.csv",
               # "siSMAD4_18dyn_16h_BSA_BMP10" : "T:/Olya/Imaging_data_flow/2021/siRNA/siSMAD4/16h/18dyn/BMP10_statistics_file.csv",
              }
print(cond_to_file)
# Out:
# {'siCTRL_static': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siCTRL/static/KLF4_siCTRL_static_merged_file.csv', 'siCTRL_4h': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siCTRL/4h/KLF4_siCTRL_4h_merged_file.csv', 'siCTRL_16h': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siCTRL/16h/KLF4_siCTRL_16h_merged_file.csv', 'siSMAD4_static': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siSMAD4/static/KLF4_siSMAD4_static_merged_file.csv', 'siSMAD4_4h': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siSMAD4/4h/KLF4_siSMAD4_4h_merged_file.csv', 'siSMAD4_16h': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siSMAD4/16h/KLF4_siSMAD4_16h_merged_file.csv', 'siAlk1_static': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siAlk1/static/KLF4_siAlk1_static_merged_file.csv', 'siAlk1_4h': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siAlk1/4h/KLF4_siAlk1_4h_merged_file.csv', 'siAlk1_16h': 'T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/siAlk1/16h/KLF4_siAlk1_16
# ...

# %%
data = pd.DataFrame()

columns_keep = ['filename',	'short_name',	'marker_mean_expression_nuc',	'marker_mean_expression_cyt',	'nuc_to_cytosol_ratio']


for cond in cond_to_file:
    print(cond)
    
    cond_data = pd.read_csv(cond_to_file[cond])
    print(cond_data.columns)
        
    cond_data_ = cond_data[columns_keep]
    cond_data_["short_name"] = cond
    

    if len(data.index) < 3:
        data = cond_data_.copy()
    else:
        data = data.append(cond_data_, ignore_index = True)

data
# Out:
# siCTRL_static
# Index(['filename', 'short_name', 'marker_mean_expression_nuc',
#        'marker_mean_expression_cyt', 'nuc_to_cytosol_ratio'],
#       dtype='object')
# siCTRL_4h
# Index(['filename', 'short_name', 'marker_mean_expression_nuc',
#        'marker_mean_expression_cyt', 'nuc_to_cytosol_ratio'],
#       dtype='object')
# siCTRL_16h
# Index(['filename', 'short_name', 'marker_mean_expression_nuc',
#        'marker_mean_expression_cyt', 'nuc_to_cytosol_ratio'],
#       dtype='object')
# siSMAD4_static
# Index(['filename', 'short_name', 'marker_mean_expression_nuc',
#        'marker_mean_expression_cyt', 'nuc_to_cytosol_ratio'],
#       dtype='object')
# siSMAD4_4h
# Index(['filename', 'short_name', 'marker_mean_expression_nuc',
#        'marker_mean_expression_cyt', 'nuc_to_cytosol_ratio'],
#       dtype='object')
# siSMAD4_16h
# Index(['filename', 'short_name', 'marker_mean_expression_nuc',
#        'marker_mean_expression_cyt', 'nuc_to_cytosol_ratio'],
# ...

# %%
data.to_csv("T:/Olya/Imaging_data_flow/2023/MV2_Promocell/KLF4/summary_table_KLF4_MV2.csv")
